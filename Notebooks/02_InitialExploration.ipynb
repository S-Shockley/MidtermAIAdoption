# %% [markdown]
# This notebook is exploratory. The goal is to experiment with charts to get an overview of the data and find more questions to base additional calculations off of.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sqlite3

# %%
#Create dataframes
df_industry = pd.read_csv("../Data/ai_industry_summary.csv")

# %%
df_company = pd.read_csv("../Data/ai_company_adoption.csv")

# %%
df_country = pd.read_csv("../Data/country_ai_index.csv")

# %% [markdown]
# Initial testing brought me to the conclusion that correlation analysis would be valuable. The next few blocks explore overall dataset correlation.

# %%
# I want to merge country to company for broad correlation
ai_analysis = df_company.merge(
    df_country,
    on=["country", "region"],
    how="left"
)

ai_analysis.head()
# Out:
#    response_id  company_id  survey_year quarter country  region   industry  \
# 0            1  COMP-00001         2023      Q1   Italy  Europe  Education
# 1            2  COMP-00001         2023      Q2   Italy  Europe  Education
# 2            3  COMP-00001         2023      Q3   Italy  Europe  Education
# 3            4  COMP-00001         2023      Q4   Italy  Europe  Education
# 4            5  COMP-00001         2024      Q1   Italy  Europe  Education
#
#   company_size  num_employees  annual_revenue_usd_millions  ...  \
# 0      Startup             57                        48.31  ...
# 1      Startup             57                        48.31  ...
# 2      Startup             57                        48.31  ...
# 3      Startup             57                        48.31  ...
# 4      Startup             57                        48.31  ...
#
#    innovation_score  customer_satisfaction              survey_source  \
# 0                53                   5.20                 WEF Survey
# 1                51                   6.98            McKinsey Report
# 2                40                   4.12  Internal Corporate Survey
# 3                51                   5.72  Internal Corporate Survey
# 4                43                   6.31            McKinsey Report
#
#    data_collection_method gdp_per_capita  internet_penetration  \
# 0              API Scrape       39436.63                 86.01
# 1         Phone Interview       39436.63                 86.01
# 2    Research Compilation       39436.63                 86.01
# 3    Research Compilation       39436.63                 86.01
# 4    Research Compilation       39436.63                 86.01
#
#   digital_maturity_index  country_ai_policy ai_patent_filings_2024  \
# 0                  75.65           Moderate                   2234
# 1                  75.65           Moderate                   2234
# 2                  75.65           Moderate                   2234
# 3                  75.65           Moderate                   2234
# 4                  75.65           Moderate                   2234
#
#    ai_researchers_per_million
# 0                      296.83
# 1                      296.83
# 2                      296.83
# 3                      296.83
# 4                      296.83
#
# [5 rows x 49 columns]

# %%
# For the merge we did not get any null values -synthetic data is complete
ai_analysis.isnull().sum()
# Out:
# response_id                    0
# company_id                     0
# survey_year                    0
# quarter                        0
# country                        0
# region                         0
# industry                       0
# company_size                   0
# num_employees                  0
# annual_revenue_usd_millions    0
# company_founding_year          0
# company_age                    0
# company_age_group              0
# ai_adoption_rate               0
# ai_adoption_stage              0
# years_using_ai                 0
# ai_primary_tool                0
# num_ai_tools_used              0
# ai_use_case                    0
# ai_projects_active             0
# ai_training_hours              0
# ai_budget_percentage           0
# ai_maturity_score              0
# ai_failure_rate                0
# ai_investment_per_employee     0
# regulatory_compliance_score    0
# data_privacy_level             0
# ai_ethics_committee            0
# ai_risk_management_score       0
# remote_work_percentage         0
# employee_satisfaction_score    0
# task_automation_rate           0
# time_saved_per_week            0
# productivity_change_percent    0
# jobs_displaced                 0
# jobs_created                   0
# reskilled_employees            0
# revenue_growth_percent         0
# cost_reduction_percent         0
# innovation_score               0
# customer_satisfaction          0
# survey_source                  0
# data_collection_method         0
# gdp_per_capita                 0
# internet_penetration           0
# digital_maturity_index         0
# country_ai_policy              0
# ai_patent_filings_2024         0
# ai_researchers_per_million     0
# dtype: int64

# %%
#This variable chooses and organizes columns for a massive correlation matrix
corr_df = ai_analysis[
    [
        # AI adoption 
        "ai_adoption_rate",
        "years_using_ai",
        "num_ai_tools_used",
        "ai_training_hours",
        "ai_budget_percentage",
        "ai_maturity_score",
        # Governance / risk
        "ai_failure_rate",
        "ai_risk_management_score",
        # Automation
        "task_automation_rate",
        # Business outcomes
        "productivity_change_percent",
        "revenue_growth_percent",
        "cost_reduction_percent",
        "innovation_score",
        "customer_satisfaction",
        # Workforce impact
        "jobs_created",
        "jobs_displaced",
        "reskilled_employees",
        "num_employees",
        # Country factors
        "gdp_per_capita",
        "internet_penetration",
        "digital_maturity_index",
        "ai_patent_filings_2024",
        "ai_researchers_per_million"
    ]
]

# %%
""""
The correlation matrix had a few interesting findings involving workforce changes, 
which drove the next stage of analysis
"""
corr_matrix = corr_df.corr()

corr_matrix
# Out:
#                              ai_adoption_rate  years_using_ai  \
# ai_adoption_rate                     1.000000        0.194012
# years_using_ai                       0.194012        1.000000
# num_ai_tools_used                    0.539365        0.118055
# ai_training_hours                    0.728420        0.134539
# ai_budget_percentage                 0.744476        0.138527
# ai_maturity_score                    0.841339        0.155064
# ai_failure_rate                     -0.657283       -0.098316
# ai_risk_management_score             0.371078        0.065638
# task_automation_rate                 0.703631        0.134012
# productivity_change_percent          0.674973        0.116494
# revenue_growth_percent               0.406839        0.072800
# cost_reduction_percent               0.404302        0.072870
# innovation_score                     0.509864        0.091466
# customer_satisfaction                0.422141        0.068908
# jobs_created                         0.305982        0.038894
# jobs_displaced                       0.278499        0.034030
# reskilled_employees                  0.268673        0.034274
# num_employees                        0.179024        0.023035
# gdp_per_capita                       0.084071        0.017045
# internet_penetration                 0.065313        0.012622
# digital_maturity_index               0.065344        0.014992
# ai_patent_filings_2024               0.020530        0.010896
# ai_researchers_per_million           0.066572        0.014742
#
#                              num_ai_tools_used  ai_training_hours  \
# ai_adoption_rate                      0.539365           0.728420
# years_using_ai                        0.118055           0.134539
# num_ai_tools_used                     1.000000           0.393811
# ai_training_hours                     0.393811           1.000000
# ai_budget_percentage                  0.400556           0.560236
# ai_maturity_score                     0.454016           0.821696
# ai_failure_rate                      -0.351571          -0.739570
# ai_risk_management_score              0.201708           0.365538
# task_automation_rate                  0.379691           0.513259
# productivity_change_percent           0.364423           0.633740
# revenue_growth_percent                0.216696           0.347841
# cost_reduction_percent                0.218866           0.328314
# innovation_score                      0.274924           0.444496
# customer_satisfaction                 0.226932           0.415638
# jobs_created                          0.164251           0.301574
# jobs_displaced                        0.150138           0.275714
# reskilled_employees                   0.144899           0.344071
# num_employees                         0.095097           0.212653
# gdp_per_capita                        0.045352           0.058913
# internet_penetration                  0.034089           0.045288
# digital_maturity_index                0.033821           0.044919
# ai_patent_filings_2024                0.011109           0.012355
# ai_researchers_per_million            0.035215           0.046201
#
#                              ai_budget_percentage  ai_maturity_score  \
# ai_adoption_rate                         0.744476           0.841339
# years_using_ai                           0.138527           0.155064
# num_ai_tools_used                        0.400556           0.454016
# ai_training_hours                        0.560236           0.821696
# ai_budget_percentage                     1.000000           0.819248
# ai_maturity_score                        0.819248           1.000000
# ai_failure_rate                         -0.527048          -0.697749
# ai_risk_management_score                 0.367073           0.445840
# task_automation_rate                     0.517041           0.590048
# productivity_change_percent              0.604105           0.737314
# revenue_growth_percent                   0.340629           0.403190
# cost_reduction_percent                   0.328713           0.386162
# innovation_score                         0.445472           0.531790
# customer_satisfaction                    0.368443           0.458789
# jobs_created                             0.356931           0.398065
# jobs_displaced                           0.327195           0.364793
# reskilled_employees                      0.321456           0.388040
# num_employees                            0.271892           0.298857
# gdp_per_capita                           0.058674           0.065990
# internet_penetration                     0.045336           0.050482
# digital_maturity_index                   0.043950           0.049445
# ai_patent_filings_2024                   0.011948           0.013477
# ai_researchers_per_million               0.046661           0.051881
#
#                              ai_failure_rate  ai_risk_management_score  \
# ai_adoption_rate                   -0.657283                  0.371078
# years_using_ai                     -0.098316                  0.065638
# num_ai_tools_used                  -0.351571                  0.201708
# ai_training_hours                  -0.739570                  0.365538
# ai_budget_percentage               -0.527048                  0.367073
# ai_maturity_score                  -0.697749                  0.445840
# ai_failure_rate                     1.000000                 -0.312925
# ai_risk_management_score           -0.312925                  1.000000
# task_automation_rate               -0.462539                  0.258595
# productivity_change_percent        -0.593667                  0.328775
# revenue_growth_percent             -0.322041                  0.180570
# cost_reduction_percent             -0.288156                  0.171646
# innovation_score                   -0.385851                  0.236262
# customer_satisfaction              -0.434765                  0.204855
# jobs_created                       -0.259982                  0.207998
# jobs_displaced                     -0.237706                  0.190840
# reskilled_employees                -0.272529                  0.202653
# num_employees                      -0.179474                  0.167333
# gdp_per_capita                     -0.055131                  0.026329
# internet_penetration               -0.043751                  0.022883
# digital_maturity_index             -0.042467                  0.018935
# ai_patent_filings_2024             -0.012411                  0.002168
# ai_researchers_per_million         -0.043397                  0.019227
#
#                              task_automation_rate  \
# ai_adoption_rate                         0.703631
# years_using_ai                           0.134012
# num_ai_tools_used                        0.379691
# ai_training_hours                        0.513259
# ai_budget_percentage                     0.517041
# ai_maturity_score                        0.590048
# ai_failure_rate                         -0.462539
# ai_risk_management_score                 0.258595
# task_automation_rate                     1.000000
# productivity_change_percent              0.582721
# revenue_growth_percent                   0.327373
# cost_reduction_percent                   0.484362
# innovation_score                         0.355491
# customer_satisfaction                    0.345878
# jobs_created                             0.216635
# jobs_displaced                           0.286413
# reskilled_employees                      0.190246
# num_employees                            0.126533
# gdp_per_capita                           0.062197
# internet_penetration                     0.049653
# digital_maturity_index                   0.051581
# ai_patent_filings_2024                   0.019071
# ai_researchers_per_million               0.052065
#
#                              productivity_change_percent  ...  \
# ai_adoption_rate                                0.674973  ...
# years_using_ai                                  0.116494  ...
# num_ai_tools_used                               0.364423  ...
# ai_training_hours                               0.633740  ...
# ai_budget_percentage                            0.604105  ...
# ai_maturity_score                               0.737314  ...
# ai_failure_rate                                -0.593667  ...
# ai_risk_management_score                        0.328775  ...
# task_automation_rate                            0.582721  ...
# productivity_change_percent                     1.000000  ...
# revenue_growth_percent                          0.476247  ...
# cost_reduction_percent                          0.345855  ...
# innovation_score                                0.405074  ...
# customer_satisfaction                           0.569821  ...
# jobs_created                                    0.291897  ...
# jobs_displaced                                  0.287572  ...
# reskilled_employees                             0.282751  ...
# num_employees                                   0.207824  ...
# gdp_per_capita                                  0.051191  ...
# internet_penetration                            0.039234  ...
# digital_maturity_index                          0.040381  ...
# ai_patent_filings_2024                          0.014018  ...
# ai_researchers_per_million                      0.040627  ...
#
#                              customer_satisfaction  jobs_created  \
# ai_adoption_rate                          0.422141      0.305982
# years_using_ai                            0.068908      0.038894
# num_ai_tools_used                         0.226932      0.164251
# ai_training_hours                         0.415638      0.301574
# ai_budget_percentage                      0.368443      0.356931
# ai_maturity_score                         0.458789      0.398065
# ai_failure_rate                          -0.434765     -0.259982
# ai_risk_management_score                  0.204855      0.207998
# task_automation_rate                      0.345878      0.216635
# productivity_change_percent               0.569821      0.291897
# revenue_growth_percent                    0.277019      0.157949
# cost_reduction_percent                    0.205888      0.149631
# innovation_score                          0.248808      0.208862
# customer_satisfaction                     1.000000      0.177026
# jobs_created                              0.177026      1.000000
# jobs_displaced                            0.172427      0.923838
# reskilled_employees                       0.174794      0.923788
# num_employees                             0.124257      0.932788
# gdp_per_capita                            0.027870      0.010714
# internet_penetration                      0.020205      0.007137
# digital_maturity_index                    0.021847      0.004297
# ai_patent_filings_2024                    0.008799      0.002751
# ai_researchers_per_million                0.020718      0.009280
#
#                              jobs_displaced  reskilled_employees  \
# ai_adoption_rate                   0.278499             0.268673
# years_using_ai                     0.034030             0.034274
# num_ai_tools_used                  0.150138             0.144899
# ai_training_hours                  0.275714             0.344071
# ai_budget_percentage               0.327195             0.321456
# ai_maturity_score                  0.364793             0.388040
# ai_failure_rate                   -0.237706            -0.272529
# ai_risk_management_score           0.190840             0.202653
# task_automation_rate               0.286413             0.190246
# productivity_change_percent        0.287572             0.282751
# revenue_growth_percent             0.150825             0.148254
# cost_reduction_percent             0.173077             0.135670
# innovation_score                   0.191002             0.197643
# customer_satisfaction              0.172427             0.174794
# jobs_created                       0.923838             0.923788
# jobs_displaced                     1.000000             0.876548
# reskilled_employees                0.876548             1.000000
# num_employees                      0.895889             0.901693
# gdp_per_capita                     0.010618             0.008130
# internet_penetration               0.007912             0.005031
# digital_maturity_index             0.004977             0.001704
# ai_patent_filings_2024             0.003813             0.000844
# ai_researchers_per_million         0.009954             0.007046
#
#                              num_employees  gdp_per_capita  \
# ai_adoption_rate                  0.179024        0.084071
# years_using_ai                    0.023035        0.017045
# num_ai_tools_used                 0.095097        0.045352
# ai_training_hours                 0.212653        0.058913
# ai_budget_percentage              0.271892        0.058674
# ai_maturity_score                 0.298857        0.065990
# ai_failure_rate                  -0.179474       -0.055131
# ai_risk_management_score          0.167333        0.026329
# task_automation_rate              0.126533        0.062197
# productivity_change_percent       0.207824        0.051191
# revenue_growth_percent            0.106251        0.033510
# cost_reduction_percent            0.097283        0.033970
# innovation_score                  0.146234        0.044226
# customer_satisfaction             0.124257        0.027870
# jobs_created                      0.932788        0.010714
# jobs_displaced                    0.895889        0.010618
# reskilled_employees               0.901693        0.008130
# num_employees                     1.000000       -0.000867
# gdp_per_capita                   -0.000867        1.000000
# internet_penetration             -0.000628        0.850398
# digital_maturity_index           -0.005373        0.863779
# ai_patent_filings_2024           -0.000527        0.413480
# ai_researchers_per_million        0.000570        0.932110
#
#                              internet_penetration  digital_maturity_index  \
# ai_adoption_rate                         0.065313                0.065344
# years_using_ai                           0.012622                0.014992
# num_ai_tools_used                        0.034089                0.033821
# ai_training_hours                        0.045288                0.044919
# ai_budget_percentage                     0.045336                0.043950
# ai_maturity_score                        0.050482                0.049445
# ai_failure_rate                         -0.043751               -0.042467
# ai_risk_management_score                 0.022883                0.018935
# task_automation_rate                     0.049653                0.051581
# productivity_change_percent              0.039234                0.040381
# revenue_growth_percent                   0.025764                0.025730
# cost_reduction_percent                   0.026026                0.027310
# innovation_score                         0.036160                0.035788
# customer_satisfaction                    0.020205                0.021847
# jobs_created                             0.007137                0.004297
# jobs_displaced                           0.007912                0.004977
# reskilled_employees                      0.005031                0.001704
# num_employees                           -0.000628               -0.005373
# gdp_per_capita                           0.850398                0.863779
# internet_penetration                     1.000000                0.836036
# digital_maturity_index                   0.836036                1.000000
# ai_patent_filings_2024                   0.305003                0.550226
# ai_researchers_per_million               0.840790                0.952405
#
#                              ai_patent_filings_2024  \
# ai_adoption_rate                           0.020530
# years_using_ai                             0.010896
# num_ai_tools_used                          0.011109
# ai_training_hours                          0.012355
# ai_budget_percentage                       0.011948
# ai_maturity_score                          0.013477
# ai_failure_rate                           -0.012411
# ai_risk_management_score                   0.002168
# task_automation_rate                       0.019071
# productivity_change_percent                0.014018
# revenue_growth_percent                     0.008482
# cost_reduction_percent                     0.008916
# innovation_score                           0.009269
# customer_satisfaction                      0.008799
# jobs_created                               0.002751
# jobs_displaced                             0.003813
# reskilled_employees                        0.000844
# num_employees                             -0.000527
# gdp_per_capita                             0.413480
# internet_penetration                       0.305003
# digital_maturity_index                     0.550226
# ai_patent_filings_2024                     1.000000
# ai_researchers_per_million                 0.527008
#
#                              ai_researchers_per_million
# ai_adoption_rate                               0.066572
# years_using_ai                                 0.014742
# num_ai_tools_used                              0.035215
# ai_training_hours                              0.046201
# ai_budget_percentage                           0.046661
# ai_maturity_score                              0.051881
# ai_failure_rate                               -0.043397
# ai_risk_management_score                       0.019227
# task_automation_rate                           0.052065
# productivity_change_percent                    0.040627
# revenue_growth_percent                         0.026699
# cost_reduction_percent                         0.027873
# innovation_score                               0.036824
# customer_satisfaction                          0.020718
# jobs_created                                   0.009280
# jobs_displaced                                 0.009954
# reskilled_employees                            0.007046
# num_employees                                  0.000570
# gdp_per_capita                                 0.932110
# internet_penetration                           0.840790
# digital_maturity_index                         0.952405
# ai_patent_filings_2024                         0.527008
# ai_researchers_per_million                     1.000000
#
# [23 rows x 23 columns]

# %%
#Plotting the matrix
#The matrix is large, but drew my attention to the workforce changes

plt.figure(figsize=(14,10))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    vmin=-1,
    vmax=1
)

plt.title("Correlation Matrix of AI Adoption, Workforce, and Business Factors")

plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

plt.tight_layout()

plt.show()

# %%
# This flattens the correlation matrix and lets us grab just the strongest pairs
corr_pairs = (corr_matrix.unstack().reset_index())
# rename the columns
corr_pairs.columns = [ "Variable 1","Variable 2","Correlation"]
# don't count self correlation
corr_pairs = corr_pairs[corr_pairs["Variable 1"] != corr_pairs["Variable 2"]]

corr_pairs.sort_values("Correlation",ascending=False).head(10)
# Out:
#                      Variable 1                  Variable 2  Correlation
# 482      digital_maturity_index  ai_researchers_per_million     0.952405
# 526  ai_researchers_per_million      digital_maturity_index     0.952405
# 339                jobs_created               num_employees     0.932788
# 405               num_employees                jobs_created     0.932788
# 436              gdp_per_capita  ai_researchers_per_million     0.932110
# 524  ai_researchers_per_million              gdp_per_capita     0.932110
# 359              jobs_displaced                jobs_created     0.923838
# 337                jobs_created              jobs_displaced     0.923838
# 338                jobs_created         reskilled_employees     0.923788
# 382         reskilled_employees                jobs_created     0.923788

# %% [markdown]
# After evaluating the large correlation matrix, I found that investigating workforce changes like jobs created/ displaced and reskilled employees would prove interesting. To explore the job changes, I am going to use a new notebook.

# %%
sns.violinplot(
    data=df_company,
    x="ai_adoption_stage",
    y="productivity_change_percent",
    order=[
        "none",
        "pilot",
        "partial",
        "full"
    ]
)
# Out:
# <Axes: xlabel='ai_adoption_stage', ylabel='productivity_change_percent'>
